# %% [markdown]
# ### Midterm
#
# Data Analytics Foundations | Submitted by Yoli Fung  | 10/13/24

# %%
# data source: https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/Salaries.csv

# %% [markdown]
# ### Research Questions
# Here are my open ended questions.
#
# 1. Determine who has the maximum salary.
# 2. Determine count of male and female with associate professor rank.
# 3. Plot salaries vs. service years.
# 4. Determine average salary by job level.
# 5. Determine if each worker is earning above or below average salary for their level.

# %% [markdown]
# ### Data Acquisition
# Data collection/ gathering/ acquisition techniques
#
# 1. Import pandas
# 2. Import and read a csv file
# 3. Look through the dataframe to describe the dataset

# %%
import pandas as pd

df = pd.read_csv(r'https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/Salaries.csv')

df
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0             1      Prof          B             19           18  Male  139750
# 1             2      Prof          B             20           16  Male  173200
# 2             3  AsstProf          B              4            3  Male   79750
# 3             4      Prof          B             45           39  Male  115000
# 4             5      Prof          B             40           41  Male  141500
# ..          ...       ...        ...            ...          ...   ...     ...
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# 396         397  AsstProf          A              8            4  Male   81035
#
# [397 rows x 7 columns]

# %%
# This csv dataset contains 397 rows and 7 columns.  
# The column names are listed below.
# Complete data (397 count per column), there are no null items.
# A combination of numbers and categorical names in the dataset.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     397 non-null    int64
#  1   rank           397 non-null    object
#  2   discipline     397 non-null    object
#  3   yrs.since.phd  397 non-null    int64
#  4   yrs.service    397 non-null    int64
#  5   sex            397 non-null    object
#  6   salary         397 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 21.8+ KB

# %%
pd.set_option('display.max.rows',400)
pd.set_option('display.max.columns',10)

# %%
df
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0             1       Prof          B             19           18    Male
# 1             2       Prof          B             20           16    Male
# 2             3   AsstProf          B              4            3    Male
# 3             4       Prof          B             45           39    Male
# 4             5       Prof          B             40           41    Male
# 5             6  AssocProf          B              6            6    Male
# 6             7       Prof          B             30           23    Male
# 7             8       Prof          B             45           45    Male
# 8             9       Prof          B             21           20    Male
# 9            10       Prof          B             18           18  Female
# 10           11  AssocProf          B             12            8    Male
# 11           12   AsstProf          B              7            2    Male
# ...

# %% [markdown]
# ### Data Wrangling 1
# Data Wrangling strategy for answering your research questions
#
# 1. Determine who has the maximum salary.

# %%
# Answer: maximum salary $231,545

df.describe()
# Out:
#        Unnamed: 0  yrs.since.phd  yrs.service         salary
# count  397.000000     397.000000   397.000000     397.000000
# mean   199.000000      22.314861    17.614610  113706.458438
# std    114.748275      12.887003    13.006024   30289.038695
# min      1.000000       1.000000     0.000000   57800.000000
# 25%    100.000000      12.000000     7.000000   91000.000000
# 50%    199.000000      21.000000    16.000000  107300.000000
# 75%    298.000000      32.000000    27.000000  134185.000000
# max    397.000000      56.000000    60.000000  231545.000000

# %%
# Alternative way to get maximum salary $231,545

df['salary'].max()
# Out:
# 231545

# %%
# index = 43
# Info about the highest earning salary $231,545
# This is a male professor, teaching in B discipline, 38 years since PHD, and 38 years in service.

df[df['salary'] == 231545]
# Out:
#     Unnamed: 0  rank discipline  yrs.since.phd  yrs.service   sex  salary
# 43          44  Prof          B             38           38  Male  231545

# %% [markdown]
# ### Data Wrangling 2
# Data Wrangling strategy for answering your research questions
#
# 2.  Determine count of male and female with associate professor rank.

# %%
# The whole dataset of Associate Professor rank

df[df['rank'].str.contains('Assoc')]
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 5             6  AssocProf          B              6            6    Male
# 10           11  AssocProf          B             12            8    Male
# 24           25  AssocProf          A             13            8  Female
# 39           40  AssocProf          B              9            9    Male
# 41           42  AssocProf          B             23           23    Male
# 54           55  AssocProf          B             12           11    Male
# 55           56  AssocProf          B             14            5    Male
# 57           58  AssocProf          B              9            8    Male
# 58           59  AssocProf          B             10            9    Male
# 60           61  AssocProf          B              9            8    Male
# 63           64  AssocProf          B             11           11  Female
# 65           66  AssocProf          B              9            8    Male
# ...

# %%
# The whole dataset of Associate Professor rank sorted by sex

df[df['rank'].str.contains('Assoc')].sort_values(by = ['sex'])
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 316         317  AssocProf          B             12            9  Female
# 123         124  AssocProf          A             25           22  Female
# 218         219  AssocProf          B             14            7  Female
# 132         133  AssocProf          A             10            8  Female
# 63           64  AssocProf          B             11           11  Female
# 153         154  AssocProf          B             12           10  Female
# 231         232  AssocProf          A             26           24  Female
# 334         335  AssocProf          B             19            6  Female
# 24           25  AssocProf          A             13            8  Female
# 186         187  AssocProf          B             13           10  Female
# 195         196  AssocProf          B              9            7    Male
# 227         228  AssocProf          A              9            7    Male
# ...

# %%
# Group by multiple columns and get the count of male and females with Associate Professor rank
# Look at the first column ('Unnamed:0')
# Answer is: There is a total of 64 people with the Associate Professor rank, 10 female and 54 male

df.groupby(['rank','sex']).count()
# Out:
#                   Unnamed: 0  discipline  yrs.since.phd  yrs.service  salary
# rank      sex
# AssocProf Female          10          10             10           10      10
#           Male            54          54             54           54      54
# AsstProf  Female          11          11             11           11      11
#           Male            56          56             56           56      56
# Prof      Female          18          18             18           18      18
#           Male           248         248            248          248     248

# %% [markdown]
# ### Data Wrangling 3
# Data Wrangling strategy for answering your research questions
#
# 3.  Plot salaries vs. service years.

# %%
# Plot both variables in a scatter plot to see if there is a relationship
# Data wrangling 1, the mean years of service = 17.6, the mean salary = $113,706
# Concentration of lower left handside

df.plot.scatter(x='yrs.service', y='salary', title='Service years vs. Salaries')
# Out:
# <Axes: title={'center': 'Service years vs. Salaries'}, xlabel='yrs.service', ylabel='salary'>

# %% [markdown]
# ### Data Wrangling 4
# Data Wrangling strategy for answering your research questions
#
# 4.  Determine average salary by job level.

# %%
# Transform with Group By
# Add a new column 'average salary per rank' into the dataframe
# Answer: Average salary per rank

df['average salary per rank'] = df.groupby('rank')['salary'].transform('mean')

# %%
df
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0             1       Prof          B             19           18    Male
# 1             2       Prof          B             20           16    Male
# 2             3   AsstProf          B              4            3    Male
# 3             4       Prof          B             45           39    Male
# 4             5       Prof          B             40           41    Male
# 5             6  AssocProf          B              6            6    Male
# 6             7       Prof          B             30           23    Male
# 7             8       Prof          B             45           45    Male
# 8             9       Prof          B             21           20    Male
# 9            10       Prof          B             18           18  Female
# 10           11  AssocProf          B             12            8    Male
# 11           12   AsstProf          B              7            2    Male
# ...

# %% [markdown]
# ### Data Wrangling 5
# Data Wrangling strategy for answering your research questions
#
# 5.  Determine if each worker is earning above or below average salary for their level.

# %%
# Use another transform formula
# Add a new column field above_below average
# Answer: Any with a positive number means above average, while a negative number means below average.

df['above_below_average'] = df.groupby('rank')['salary'].transform(lambda x: x - x.mean())

# %%
df
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0             1       Prof          B             19           18    Male
# 1             2       Prof          B             20           16    Male
# 2             3   AsstProf          B              4            3    Male
# 3             4       Prof          B             45           39    Male
# 4             5       Prof          B             40           41    Male
# 5             6  AssocProf          B              6            6    Male
# 6             7       Prof          B             30           23    Male
# 7             8       Prof          B             45           45    Male
# 8             9       Prof          B             21           20    Male
# 9            10       Prof          B             18           18  Female
# 10           11  AssocProf          B             12            8    Male
# 11           12   AsstProf          B              7            2    Male
# ...

# %% [markdown]
# ### EDA 2.B
# Plotting Question 2
#
# 1. Filter out Associate Professor
# 2. Groupby Sex
# 3. Count by Rank
# 4. Data visualization as a pie chart

# %%
# Visualize the answer from Question 2
# Out of all Associate Professor, we can see Male dominates over Female (54 vs 10)

df[df['rank']== ('AssocProf')].groupby('sex')['rank'].count().plot(kind = 'pie', title = 'Male/Female ratio Assoc Prof')
# Out:
# <Axes: title={'center': 'Male/Female ratio Assoc Prof'}, ylabel='rank'>

# %% [markdown]
# ### EDA 5.B
# Plotting Question 5

# %%
# Visualize the answer from Question 2
# This takes all salaried teachers and show how far they were from the average salary within their rank
# It looks like majority are below the average salary range for their rank, 218 (see estimated calculations below)


df['above_below_average'].plot(kind='hist', title = 'Histogram of Salary above or below Average')
# Out:
# <Axes: title={'center': 'Histogram of Salary above or below Average'}, ylabel='Frequency'>

# %%
# Total people = 397
# Below average salary estimated = 218

all_1 = 117
all_2 = 80
all_3 = 20
all_4 = 1

total_all = all_1 + all_2 + all_3 + all_4
print(total_all)
# Out:
# 218

# %%
df.groupby('rank').count()
# Out:
#            Unnamed: 0  discipline  yrs.since.phd  yrs.service  sex  salary  \
# rank
# AssocProf          64          64             64           64   64      64
# AsstProf           67          67             67           67   67      67
# Prof              266         266            266          266  266     266
#
#            average salary per rank  above_below_average
# rank
# AssocProf                       64                   64
# AsstProf                        67                   67
# Prof                           266                  266

# %%
# Looking at Assistant Professors only
# About roughly the same below and above average salary

df[df['rank']== ('AsstProf')]['above_below_average'].plot(kind='hist', title = 'Histogram of Assistant Professor Salary above or below Average')
# Out:
# <Axes: title={'center': 'Histogram of Assistant Professor Salary above or below Average'}, ylabel='Frequency'>

# %%
# Total people = 67
# Below average salary estimated = 35

all_12 = 10
all_22 = 10
all_32 = 8
all_42 = 5
all_52 = 2

total_all2 = all_12 + all_22 + all_32 + all_42 + all_52
print(total_all2)
# Out:
# 35

# %%
# Looking at Associate Professors only
# Slightly more above average salary, 35 (see below calculations)

df[df['rank']== ('AssocProf')]['above_below_average'].plot(kind='hist', title = 'Histogram of Associate Professor Salary above or below Average')
# Out:
# <Axes: title={'center': 'Histogram of Associate Professor Salary above or below Average'}, ylabel='Frequency'>

# %%
# Total people = 64
# Below average salary estimated = 29

all_13 = 6
all_23 = 9
all_33 = 6
all_43 = 7
all_53 = 1

total_all3 = all_13 + all_23 + all_33 + all_43 + all_53
print(total_all3)
# Out:
# 29

# %%
x = 64 - 29

# %%
print(x)
# Out:
# 35

# %%
# Looking at Professors only
# More below average salary, 148 (see below calculations)

df[df['rank']== ('Prof')]['above_below_average'].plot(kind='hist', title = 'Histogram of Professor Salary above or below Average')
# Out:
# <Axes: title={'center': 'Histogram of Professor Salary above or below Average'}, ylabel='Frequency'>

# %%
# Total people = 266
# Below average salary estimated = 148

all_14 = 60
all_24 = 68
all_34 = 17
all_44 = 3

total_all4 = all_14 + all_24 + all_34 + all_44
print(total_all4)
# Out:
# 148

# %%
c = 266 - 148
print(c)
# Out:
# 118

# %% [markdown]
# # Conclusion
# 1.  Surprising to see there are very few female teachers.
# 2.  I will need more time and more advanced statistics to see the relationship between the years (education/service) and salary.
# 3.  The scatterplot shows that fewer years in the workforce will have a lower salary.
# 4.  I do not have much information about what is discipline A versus B.  I cannot say if discipline has an impact to the salary.
# 5.  The shape of the histogram for salary on all rank levels shows fairly distributed below and above average salary.
# 6.  It is when drilling down to the different ranks that we see much differences in salary range.
# 7.  With Professor level, getting paid more compared to Assistant and Associate, but also seeing a large percentage of Professors are below the average within the rank level.
